# %% [markdown]
# # Python Programming 101
#
# ## Dr J Rogel-Salazar
# ### [j.rogel.datascience@gmail.com](mailto:j.rogel.datascience@gmail.com)
#
# ## General Assembly - Demo for Plotly
#
# This notebook contains a demo for Plotly

# %%
# Obligatory 'Hello World' example
print('Hello World')
# Out:
# Hello World

# %%
x = 1
x
# Out:
# 1

# %% [markdown]
# ### Plotly
# A nice open source library for interactive visualisations

# %%
# To run any command at the system shell, simply prefix it with !
# pip won't work from inside python without it
# !pip install plotly --upgrade
# Out:
# Collecting plotly
#   Downloading plotly-2.0.11.tar.gz (1.0MB)
#     100% |################################| 1.0MB 669kB/s ta 0:00:01
# Collecting decorator>=4.0.6 (from plotly)
#   Downloading decorator-4.0.11-py2.py3-none-any.whl
# Requirement already up-to-date: nbformat>=4.2 in /Users/xantheterra/miniconda3/lib/python3.5/site-packages (from plotly)
# Collecting pytz (from plotly)
#   Downloading pytz-2017.2-py2.py3-none-any.whl (484kB)
#     100% |################################| 491kB 1.4MB/s eta 0:00:01
# Collecting requests (from plotly)
#   Downloading requests-2.18.1-py2.py3-none-any.whl (88kB)
#     100% |################################| 92kB 4.2MB/s eta 0:00:01
# Requirement already up-to-date: six in /Users/xantheterra/miniconda3/lib/python3.5/site-packages (from plotly)
# Collecting chardet<3.1.0,>=3.0.2 (from requests->plotly)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133kB)
#     100% |################################| 143kB 3.2MB/s ta 0:00:011
# Collecting urllib3<1.22,>=1.21.1 (from requests->plotly)
#   Downloading urllib3-1.21.1-py2.py3-none-any.whl (131kB)
#     100% |################################| 133kB 3.9MB/s eta 0:00:01
# Collecting idna<2.6,>=2.5 (from requests->plotly)
#   Downloading idna-2.5-py2.py3-none-any.whl (55kB)
#     100% |################################| 61kB 4.9MB/s eta 0:00:01
# Collecting certifi>=2017.4.17 (from requests->plotly)
#   Downloading certifi-2017.4.17-py2.py3-none-any.whl (375kB)
#     100% |################################| 378kB 1.5MB/s ta 0:00:011
# Building wheels for collected packages: plotly
# done
#   Stored in directory: /Users/xantheterra/Library/Caches/pip/wheels/42/0e/32/4c21416a45ad6efe5daa0a2c9fe358c54a3b4fa6223ad69922
# Successfully built plotly
# Installing collected packages: decorator, pytz, chardet, urllib3, idna, certifi, requests, plotly
#   Found existing installation: decorator 4.0.9
#     Uninstalling decorator-4.0.9:
#       Successfully uninstalled decorator-4.0.9
#   Found existing installation: pytz 2016.10
#     DEPRECATION: Uninstalling a distutils installed project (pytz) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling pytz-2016.10:
#       Successfully uninstalled pytz-2016.10
#   Found existing installation: idna 2.2
#     Uninstalling idna-2.2:
#       Successfully uninstalled idna-2.2
#   Found existing installation: requests 2.13.0
#     Uninstalling requests-2.13.0:
#       Successfully uninstalled requests-2.13.0
# Successfully installed certifi-2017.4.17 chardet-3.0.4 decorator-4.0.11 idna-2.5 plotly-2.0.11 pytz-2017.2 requests-2.18.1 urllib3-1.21.1

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

743, 0.6566295595278706, -0.8614250885303188, -0.8875262693635416, -0.0649843717617444, 0.8902773697490945, -0.3484954671893332, -2.2347837433309055, 0.34676973051178106, -0.33247345028947717, 0.9274145741621491, -0.07467235339885454, -1.0488344562772947, 0.8619312274285356, 0.5839164532104808, 0.46849201250173017, -0.23636410549295267, -0.034744487023615184, -1.6626854812669212, -1.256074222324778, 0.46139692294751034, 0.30338406742084256, 1.104722404973419, 1.2863529978680837, -0.19181242944033766, -0.11230484760973712, -0.8701406692842929, 0.02823096208219296, 1.3747133985574602, 0.5452145055777664, -0.35290811128209826, 0.3691775293682489, 0.5268915856593955, 1.9085416112681801, -0.6066732631705275, -0.20951078859787456, 0.1819329375780265, 1.7518269131174757, 0.8684380925749411, 1.0128927777832597, 0.26014095392439796, -0.43579894290031745, -0.043961437946642874, 0.38477183824396, -1.0926703798039352, -1.006127231049572, -0.6469283901657296, 1.1448806879206284, -0.5476657007159436, 0.5358176801405599, 0.8001720979768505, -0.04236321645701288, -0.11460784877714836, -1.2897092922897049, -1.1096786359861786, 0.9148614569534473, -0.2319100048295344, -1.4784798999006397, -1.6973115881009178, 0.11190502744467858, -1.8200343707303646, -0.6163707844236644, 0.18416707931209925, -1.6378610800235625, -2.601219607259163, 1.5968281497542387, -0.3815771725911291, -0.8110382606273435, 0.05234760794433675, 2.8660008072875702, 1.7034887883864176, 0.45777427258050596, -0.7180349683679069, 0.5424917095510552, -1.4319341132426013, 0.3662621357887074, -0.34748672458486374, 1.3420782482454388, 0.24561968705148837, -0.5866905992296839, 0.32742420008879664, -0.6742879949880985, -0.3587719884280017, 1.2602491363190615, 1.6007859460420089, 1.0620029368125437, 0.6488705035356559, 0.5958169363014172, -1.0706677962852345, 0.22210995881525564, -0.2979648553484548, -0.4423133959723112, 1.5417003885263878, 0.8994938686908889, 1.007120410360638, 0.5023654313419516, 0.25418718074342667, -1.2719157 ...

# %%
# Airport flight path interactive visualisaion

# %%
import pandas as pd

# %%
df_airports = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df_airports.head()

df_flight_paths = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_aa_flight_paths.csv')
df_flight_paths.head()

airports = [ dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_airports['long'],
        lat = df_airports['lat'],
        hoverinfo = 'text',
        text = df_airports['airport'],
        mode = 'markers',
        marker = dict(
            size=2,
            color='rgb(255, 0, 0)',
            line = dict(
                width=3,
                color='rgba(68, 68, 68, 0)'
            )
        ))]

flight_paths = []
for i in range( len( df_flight_paths ) ):
    flight_paths.append(
        dict(
            type = 'scattergeo',
            locationmode = 'USA-states',
            lon = [ df_flight_paths['start_lon'][i], df_flight_paths['end_lon'][i] ],
            lat = [ df_flight_paths['start_lat'][i], df_flight_paths['end_lat'][i] ],
            mode = 'lines',
            line = dict(
                width = 1,
                color = 'red',
            ),
            opacity = float(df_flight_paths['cnt'][i])/float(df_flight_paths['cnt'].max()),
        )
    )

layout = dict(
        title = 'Feb. 2011 American Airline flight paths<br>(Hover for airport names)',
        showlegend = False,
        height = 800,
        geo = dict(
            scope='north america',
            projection=dict( type='azimuthal equal area' ),
            showland = True,
            landcolor = 'rgb(243, 243, 243)',
            countrycolor = 'rgb(204, 204, 204)',
        ),
    )

fig = dict( data=flight_paths + airports, layout=layout )

iplot(fig)
# Out:
# <div id="3d72dc2b-e497-476e-95d1-2423d893d192" style="height: 800px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3d72dc2b-e497-476e-95d1-2423d893d192", [{"lat": [32.89595056, 35.04022222], "locationmode": "USA-states", "lon": [-97.0372, -106.6091944], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.48577680525164113, "mode": "lines"}, {"lat": [41.979595, 30.19453278], "locationmode": "USA-states", "lon": [-87.90446417, -97.66987194], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.18161925601750548, "mode": "lines"}, {"lat": [32.89595056, 41.93887417], "locationmode": "USA-states", "lon": [-97.0372, -72.68322833], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.1772428884026258, "mode": "lines"}, {"lat": [18.43941667, 41.93887417], "locationmode": "USA-states", "lon": [-66.00183333, -72.68322833], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.061269146608315096, "mode": "lines"}, {"lat": [32.89595056, 33.56294306], "locationmode": "USA-states", "lon": [-97.0372, -86.75354972], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.1838074398249453, "mode": "lines"}, {"lat": [25.79325, 36.12447667], "locationmode": "USA-states", "lon": [-80.29055556, -86.67818222], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.061269146608315096, "mode": "lines"}, {"lat": [32.89595056, 42.3643475], "locationmode": "USA-states", "lon": [-97.0372, -71.00517917], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.4617067833698031, "mode": "lines"}, {"lat": [25.79325, 42.3643475], "locationmode": "USA-states", "lon": [-80.29055556, -71.00517917], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.4288840262582057, "mode": "lines"}, {"lat": [41.979595, 42.3643475], "locationmode": "USA-states", "lon": [-87.90446417, -71.00517917], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.47045951859956237, "mode": "lines"}, {"lat": [18.43941667, 42.3643475], "locationmode": "USA-states", "lon": [-66.00183333, -71.00517917], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.061269146608315096, "mode": "lines"}, {"lat": [18.33730556, 42.3643475], "locationmode": "USA-states", "lon": [-64.97336111, -71.00517917], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.04814004376367615, "mode": "lines"}, {"lat": [25.79325, 39.17540167], "locationmode": "USA-states", "lon": [-80.29055556, -76.66819833], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.12253829321663019, "mode": "lines"}, {"lat": [18.43941667, 39.17540167], "locationmode": "USA-states", "lon": [-66.00183333, -76.66819833], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.061269146608315096, "mode": "lines"}, {"lat": [32.89595056, 35.21401111], "locationmode": "USA-states", "lon": [-97.0372, -80.94312583], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.3938730853391685, "mode": "lines"}, {"lat": [32.89595056, 38.80580556], "locationmode": "USA-states", "lon": [-97.0372, -104.70025], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.3041575492341357, "mode": "lines"}, {"lat": [32.89595056, 39.90237583], "locationmode": "USA-states", "lon": [-97.0372, -84.219375], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.1137855579868709, "mode": "lines"}, {"lat": [32.89595056, 38.85208333], "locationmode": "USA-states", "lon": [-97.0372, -77.03772222], "line": {"color": "red", "width": 1}, "type": "scattergeo", "opacity": 0.6433260393873085, "mode": "lines"}, {"lat": [25.79325, 39.85840806], "locationmode": "USA-states", "lon": [-80.29055556, -104.6670019], "line": {"col ...
